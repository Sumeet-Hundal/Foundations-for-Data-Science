# %%
import pandas as pd
import numpy as np
import statistics as stats
from datetime import datetime
from datetime import timedelta
beer_c=pd.read_csv("monthly-beer-production-in-austr.csv",skiprows=1,sep=",",names=['month','beer_prod'])

beer_c.head(5)
# Out:
#      month  beer_prod
# 0  1956-01       93.2
# 1  1956-02       96.0
# 2  1956-03       95.2
# 3  1956-04       77.1
# 4  1956-05       70.9

# %%
import pandas as pd
from datetime import datetime
from datetime import timedelta
from pandas import read_csv

# %%
print('1)')
beer_c['month']=pd.to_datetime(beer_c['month'],yearfirst=True)
beer_c['month'].head(2)
# Out:
# 1)
# 0   1956-01-01
# 1   1956-02-01
# Name: month, dtype: datetime64[ns]

# %%
#beer_c=pd.Series(beer_c['beer_prod'], index=beer_c['month'])
beer_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 476 entries, 0 to 475
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   month      476 non-null    datetime64[ns]
#  1   beer_prod  476 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 7.6 KB

# %%
beer_c=beer_c.set_index('month')
beer_c.head(5)
# Out:
#             beer_prod
# month
# 1956-01-01       93.2
# 1956-02-01       96.0
# 1956-03-01       95.2
# 1956-04-01       77.1
# 1956-05-01       70.9

# %%
#c2=[]

#for value in range (476):
    #c2.append([200,0])
    
#beer_c['constant']=c2
#beer_c.head(5)

# %%
timepl = beer_c.plot(title="Beer Consumption over Years",figsize=(40,10) )
timepl.set_ylabel("Beer Consumption")
timepl.set_xlabel("Months")
tmp = timepl.plot()
print('2)')
tmp
# Out:
# 2)
# []

# %%
beer_c1=beer_c.iloc[:238]
beer_c2=beer_c.iloc[238:]
timepl1 = beer_c1.plot(title="Beer Consumption over Years",figsize=(40,10) )
timepl1.set_ylabel("Beer Consumption")
timepl1.set_xlabel("Months")
tmp1 = timepl.plot()
print(tmp1)
timepl2 = beer_c2.plot(title="Beer Consumption over Years",figsize=(40,10) )
timepl2.set_ylabel("Beer Consumption")
timepl2.set_xlabel("Months")
tmp2 = timepl.plot()
print(tmp2)
# Out:
# []
# []

# %% [markdown]
# #### 2) The graph has seasonality as well as a possitive trend over the approx. 40 years. There is overall trend but there is ayearly seasonal trend as we well.

# %%
from pandas.plotting import autocorrelation_plot

# %%
temp=pd.plotting.autocorrelation_plot(beer_c)
temp

# %% [markdown]
# #### 3) The data is not autocorrelated as the data is not close to 0. By the end of  the variable data it does start to approach autocorrelation.

# %%
print('4)')
beer_cou=beer_c.diff()
beer_cou.head(5)
# Out:
# 4)
#             beer_prod
# month
# 1956-01-01        NaN
# 1956-02-01        2.8
# 1956-03-01       -0.8
# 1956-04-01      -18.1
# 1956-05-01       -6.2

# %%
beer_cou=beer_cou.fillna(0)

beer_cou.head(5)
# Out:
#             beer_prod
# month
# 1956-01-01        0.0
# 1956-02-01        2.8
# 1956-03-01       -0.8
# 1956-04-01      -18.1
# 1956-05-01       -6.2

# %%
print('5)')
temp1=pd.plotting.autocorrelation_plot(beer_cou)
temp1
# Out:
# 5)

# %%
print('5) Based on the plot, there is randomness in the data and it is not autocorrelated. There is fluctuation in the data and is not stationary. ')
# Out:
# 5) Based on the plot, there is randomness in the data and it is not autocorrelated. There is fluctuation in the data and is not stationary.

# %%
print('6)')

beer_cou1=beer_cou.iloc[:238]
beer_cou2=beer_cou.iloc[238:]

beer_cou1.head(5)
# Out:
# 6)
#             beer_prod
# month
# 1956-01-01        0.0
# 1956-02-01        2.8
# 1956-03-01       -0.8
# 1956-04-01      -18.1
# 1956-05-01       -6.2

# %%
b_m1=np.mean(beer_cou1['beer_prod'])
b_v1=pd.Series.var(beer_cou1['beer_prod'])
b_s1=np.std(beer_cou1['beer_prod'])
print('Subset 1: Mean, Variance, STD:',b_m1,b_v1,b_s1)
b_m2=np.mean(beer_cou2['beer_prod'])
b_v2=pd.Series.var(beer_cou2['beer_prod'])
b_s2=np.std(beer_cou2['beer_prod'])
print('Subset 2: Mean, Variance, STD:',b_m2,b_v2,b_s2)

print("6) We can not assume stationarity for this data as the mean and variance are not constant in the subsets which means that there is a change over time")
# Out:
# Subset 1: Mean, Variance, STD: 0.4 238.83054852320674 15.421642546224751
# Subset 2: Mean, Variance, STD: -0.14873949579831935 533.5441967166613 23.049998142679225
# 6) We can not assume stationarity for this data as the mean and variance are not constant in the subsets which means that there is a change over time

# %%
bp = beer_cou.plot(figsize=(40,10))
bp_t = timepl.plot()
bp_t
# Out:
# []

# %%
beer_cou
# Out:
#             beer_prod
# month
# 1956-01-01        0.0
# 1956-02-01        2.8
# 1956-03-01       -0.8
# 1956-04-01      -18.1
# 1956-05-01       -6.2
# ...               ...
# 1995-04-01      -25.0
# 1995-05-01       24.0
# 1995-06-01      -21.0
# 1995-07-01      -11.0
# 1995-08-01       34.0
#
# [476 rows x 1 columns]
